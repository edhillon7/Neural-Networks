# %%
import numpy as np

# %%
inputs = np.array([[0,0],[0,1],[1,0],[1,1]])

# %%
inputs.shape
# Out:
# (4, 2)

# %%
weights = np.array([0.0,0.0])

# %%
outputs = np.array([0,0,0,1])

# %%
learning_rate = 0.1

# %%
def step_function(sum):
  if (sum >= 1):
      return 1;

  return 0;

# %%
def output(s):
  sum_fn = s.dot(weights)
  return step_function(sum_fn);

# %%
output(np.array([[0,0]]))
# Out:
# 0

# %%
def train():
  total_error = 1
  while (total_error != 0):
    total_error = 0
    for i in range(len(outputs)):
      prediction = output(inputs[i])
      error = abs(outputs[i] - prediction)
      total_error += error
      if error > 0:
        for j in range(len(weights)):
          weights[j] = weights[j] + (learning_rate * inputs[i][j] * error)
          print('Weight updated: ' + str(weights[j]))
    print('Total error: ' + str(total_error))

# %%
train ()
# Out:
# Weight updated: 0.1
# Weight updated: 0.1
# Total error: 1
# Weight updated: 0.2
# Weight updated: 0.2
# Total error: 1
# Weight updated: 0.30000000000000004
# Weight updated: 0.30000000000000004
# Total error: 1
# Weight updated: 0.4
# Weight updated: 0.4
# Total error: 1
# Weight updated: 0.5
# Weight updated: 0.5
# Total error: 1
# Total error: 0
